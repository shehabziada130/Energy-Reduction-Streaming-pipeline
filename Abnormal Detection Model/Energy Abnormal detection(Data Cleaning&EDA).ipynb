# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from datetime import datetime

# %%
data=pd.read_csv('drive/MyDrive/Intent-Based Energy Reduction/Data/2018Floor3.csv')

# %%
data.shape
# Out:
# (264960, 30)

# %%
data.head()
# Out:
#                   Date  z1_AC1(kW)  z1_AC2(kW)  z1_AC3(kW)  z1_AC4(kW)  \
# 0  2018-07-01 00:00:00         0.0         0.0         0.0        0.07
# 1  2018-07-01 00:01:00         0.0         0.0         0.0        0.07
# 2  2018-07-01 00:02:00         0.0         0.0         0.0        0.07
# 3  2018-07-01 00:03:00         0.0         0.0         0.0        0.07
# 4  2018-07-01 00:04:00         0.0         0.0         0.0        0.07
#
#    z1_Light(kW)  z1_Plug(kW)  z1_S1(degC)  z1_S1(RH%)  z1_S1(lux)  ...  \
# 0           0.0         0.03        28.44       60.67         0.0  ...
# 1           0.0         0.03        28.44       60.67         0.0  ...
# 2           0.0         0.03        28.45       60.67         0.0  ...
# 3           0.0         0.03        28.45       60.66         0.0  ...
# 4           0.0         0.03        28.45       60.66         0.0  ...
#
#    z4_Plug(kW)  z4_S1(degC)  z4_S1(RH%)  z4_S1(lux)  z5_AC1(kW)  z5_Light(kW)  \
# 0         0.02        27.69       65.66         0.0         0.0           0.0
# 1         0.02        27.69       65.65         0.0         0.0           0.0
# 2         0.02        27.69       65.63         0.0         0.0           0.0
# 3         0.02          NaN         NaN         NaN         0.0           0.0
# 4         0.02          NaN         NaN         NaN         0.0           0.0
#
#    z5_Plug(kW)  z5_S1(degC)  z5_S1(RH%)  z5_S1(lux)
# 0         0.02        26.88       71.16         0.0
# 1         0.02        26.88       71.16         0.0
# 2         0.02        26.88       71.18         0.0
# 3         0.02        26.88       71.19         0.0
# 4         0.02        26.88       71.21         0.0
#
# [5 rows x 30 columns]

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 264960 entries, 0 to 264959
# Data columns (total 30 columns):
#  #   Column        Non-Null Count   Dtype
# ---  ------        --------------   -----
#  0   Date          264960 non-null  object
#  1   z1_AC1(kW)    197931 non-null  float64
#  2   z1_AC2(kW)    197931 non-null  float64
#  3   z1_AC3(kW)    197931 non-null  float64
#  4   z1_AC4(kW)    205333 non-null  float64
#  5   z1_Light(kW)  205717 non-null  float64
#  6   z1_Plug(kW)   205782 non-null  float64
#  7   z1_S1(degC)   101340 non-null  float64
#  8   z1_S1(RH%)    101340 non-null  float64
#  9   z1_S1(lux)    101340 non-null  float64
#  10  z2_AC1(kW)    205338 non-null  float64
#  11  z2_Light(kW)  205486 non-null  float64
#  12  z2_Plug(kW)   205794 non-null  float64
#  13  z2_S1(degC)   101895 non-null  float64
#  14  z2_S1(RH%)    101895 non-null  float64
#  15  z2_S1(lux)    101895 non-null  float64
#  16  z3_Light(kW)  205751 non-null  float64
#  17  z3_Plug(kW)   205744 non-null  float64
#  18  z4_AC1(kW)    205334 non-null  float64
#  19  z4_Light(kW)  205202 non-null  float64
#  20  z4_Plug(kW)   205510 non-null  float64
#  21  z4_S1(degC)   100449 non-null  float64
#  22  z4_S1(RH%)    100449 non-null  float64
#  23  z4_S1(lux)    100449 non-null  float64
#  24  z5_AC1(kW)    205334 non-null  float64
#  25  z5_Light(kW)  205202 non-null  float64
#  26  z5_Plug(kW)   205734 non-null  float64
#  27  z5_S1(degC)   70240 non-null   float64
#  28  z5_S1(RH%)    70240 non-null   float64
#  29  z5_S1(lux)    70240 non-null   float64
# dtypes: float64(29), object(1)
# memory usage: 60.6+ MB

# %%
data.iloc[:,:15].describe()
# Out:
#           z1_AC1(kW)     z1_AC2(kW)     z1_AC3(kW)     z1_AC4(kW)  \
# count  197931.000000  197931.000000  197931.000000  205333.000000
# mean        0.000906       0.001527       0.003509       4.817822
# std         0.033903       0.052491       0.062320       9.564465
# min         0.000000       0.000000       0.000000       0.000000
# 25%         0.000000       0.000000       0.000000       0.070000
# 50%         0.000000       0.000000       0.000000       0.070000
# 75%         0.000000       0.000000       0.000000       0.070000
# max         2.350000       2.870000       2.200000      55.950000
#
#         z1_Light(kW)    z1_Plug(kW)    z1_S1(degC)     z1_S1(RH%)  \
# count  205717.000000  205782.000000  101340.000000  101340.000000
# mean        1.800284       0.251956      27.329100      57.371349
# std         2.343597       0.344192       1.645793       3.950850
# min         0.000000       0.000000      22.400000      48.570000
# 25%         0.000000       0.030000      26.970000      54.210000
# 50%         0.000000       0.040000      27.760000      57.190000
# 75%         4.260000       0.480000      28.420000      59.930000
# max       162.240000      35.450000      30.900000      73.350000
#
#           z1_S1(lux)     z2_AC1(kW)   z2_Light(kW)    z2_Plug(kW)  \
# count  101340.000000  205338.000000  205486.000000  205794.000000
# mean       13.523535       3.646646       2.251236       0.310581
# std        17.709808       7.560185       2.999472       0.429756
# min         0.000000       0.000000       0.000000       0.000000
# 25%         0.000000       0.000000       0.000000       0.030000
# 50%         1.000000       0.000000       0.000000       0.040000
# 75%        35.000000       0.000000       5.900000       0.580000
# max        57.000000      59.070000     236.160000      21.420000
#
#          z2_S1(degC)     z2_S1(RH%)
# count  101895.000000  101895.000000
# mean       26.768331      59.147266
# std         1.713708       4.228938
# min        22.100000      48.110000
# 25%        26.670000      55.990000
# 50%        27.360000      58.640000
# 75%        27.850000      62.570000
# max        29.990000      70.000000

# %%
data.iloc[:,15:].describe()
# Out:
#           z2_S1(lux)   z3_Light(kW)    z3_Plug(kW)     z4_AC1(kW)  \
# count  101895.000000  205751.000000  205744.000000  205334.000000
# mean       31.133216       0.430329       0.410784       3.477475
# std        36.435368       0.448204       0.111985       7.601039
# min         0.000000       0.000000       0.000000       0.000000
# 25%         0.000000       0.010000       0.350000       0.000000
# 50%         0.000000       0.240000       0.390000       0.000000
# 75%        74.000000       0.780000       0.510000       0.000000
# max        85.000000       7.730000       5.690000      52.190000
#
#         z4_Light(kW)    z4_Plug(kW)    z4_S1(degC)     z4_S1(RH%)  \
# count  205202.000000  205510.000000  100449.000000  100449.000000
# mean        1.040262       0.207158      26.229973      61.989984
# std         1.299660       0.303266       2.348339       3.387793
# min         0.000000       0.000000      20.240000      52.290000
# 25%         0.000000       0.020000      25.940000      59.700000
# 50%         0.000000       0.020000      26.930000      62.100000
# 75%         2.810000       0.350000      27.700000      64.400000
# max        19.450000       5.080000      29.900000      73.560000
#
#           z4_S1(lux)     z5_AC1(kW)   z5_Light(kW)    z5_Plug(kW)  \
# count  100449.000000  205334.000000  205202.000000  205734.000000
# mean       10.528009       1.949805       0.720709       0.236874
# std        14.970213       4.349532       1.038938       0.317253
# min         0.000000       0.000000       0.000000       0.000000
# 25%         0.000000       0.000000       0.000000       0.020000
# 50%         0.000000       0.000000       0.000000       0.040000
# 75%        29.000000       0.000000       2.040000       0.470000
# max        52.000000      49.770000      32.970000       2.910000
#
#         z5_S1(degC)    z5_S1(RH%)    z5_S1(lux)
# count  70240.000000  70240.000000  70240.000000
# mean      25.616670     67.544492     10.836859
# std        2.066253      3.649477     15.289946
# min       19.570000     52.560000      0.000000
# 25%       25.370000     65.280000      0.000000
# 50%       26.220000     67.920000      0.000000
# 75%       26.900000     70.100000     31.000000
# max       29.900000     77.900000     44.000000

# %%
data.hist(figsize=(20,20),bins=50,xlabelsize=8,ylabelsize=8)
# Out:
# Fitting GaussianMixtures:  60%|██████    | 3/5 [46:49<31:13, 936.59s/model]
# array([[<Axes: title={'center': 'z1_AC1(kW)'}>,
#         <Axes: title={'center': 'z1_AC2(kW)'}>,
#         <Axes: title={'center': 'z1_AC3(kW)'}>,
#         <Axes: title={'center': 'z1_AC4(kW)'}>,
#         <Axes: title={'center': 'z1_Light(kW)'}>,
#         <Axes: title={'center': 'z1_Plug(kW)'}>],
#        [<Axes: title={'center': 'z1_S1(degC)'}>,
#         <Axes: title={'center': 'z1_S1(RH%)'}>,
#         <Axes: title={'center': 'z1_S1(lux)'}>,
#         <Axes: title={'center': 'z2_AC1(kW)'}>,
#         <Axes: title={'center': 'z2_Light(kW)'}>,
#         <Axes: title={'center': 'z2_Plug(kW)'}>],
#        [<Axes: title={'center': 'z2_S1(degC)'}>,
#         <Axes: title={'center': 'z2_S1(RH%)'}>,
#         <Axes: title={'center': 'z2_S1(lux)'}>,
#         <Axes: title={'center': 'z3_Light(kW)'}>,
#         <Axes: title={'center': 'z3_Plug(kW)'}>,
#         <Axes: title={'center': 'z4_AC1(kW)'}>],
#        [<Axes: title={'center': 'z4_Light(kW)'}>,
#         <Axes: title={'center': 'z4_Plug(kW)'}>,
#         <Axes: title={'center': 'z4_S1(degC)'}>,
#         <Axes: title={'center': 'z4_S1(RH%)'}>,
#         <Axes: title={'center': 'z4_S1(lux)'}>,
#         <Axes: title={'center': 'z5_AC1(kW)'}>],
#        [<Axes: title={'center': 'z5_Light(kW)'}>,
#         <Axes: title={'center': 'z5_Plug(kW)'}>,
#         <Axes: title={'center': 'z5_S1(degC)'}>,
#         <Axes: title={'center': 'z5_S1(RH%)'}>,
#         <Axes: title={'center': 'z5_S1(lux)'}>,
#         <Axes: title={'center': 'z4_AC2(kW)'}>],
#        [<Axes: title={'center': 'z4_AC3(kW)'}>,
#         <Axes: title={'center': 'z4_AC4(kW)'}>, <Axes: >, <Axes: >,
#         <Axes: >, <Axes: >]], dtype=object)

# %%
data.head()
# Out:
#                   Date  z1_AC1(kW)  z1_AC2(kW)  z1_AC3(kW)  z1_AC4(kW)  \
# 0  2018-07-01 00:00:00         0.0         0.0         0.0        0.07
# 1  2018-07-01 00:01:00         0.0         0.0         0.0        0.07
# 2  2018-07-01 00:02:00         0.0         0.0         0.0        0.07
# 3  2018-07-01 00:03:00         0.0         0.0         0.0        0.07
# 4  2018-07-01 00:04:00         0.0         0.0         0.0        0.07
#
#    z1_Light(kW)  z1_Plug(kW)  z1_S1(degC)  z1_S1(RH%)  z2_AC1(kW)  ...  \
# 0           0.0         0.03        28.44       60.67         0.0  ...
# 1           0.0         0.03        28.44       60.67         0.0  ...
# 2           0.0         0.03        28.45       60.67         0.0  ...
# 3           0.0         0.03        28.45       60.66         0.0  ...
# 4           0.0         0.03        28.45       60.66         0.0  ...
#
#    z4_AC1(kW)  z4_Light(kW)  z4_Plug(kW)  z4_S1(degC)  z4_S1(RH%)  z5_AC1(kW)  \
# 0         0.0           0.0         0.02        27.69       65.66         0.0
# 1         0.0           0.0         0.02        27.69       65.65         0.0
# 2         0.0           0.0         0.02        27.69       65.63         0.0
# 3         0.0           0.0         0.02          NaN         NaN         0.0
# 4         0.0           0.0         0.02          NaN         NaN         0.0
#
#    z5_Light(kW)  z5_Plug(kW)  z5_S1(degC)  z5_S1(RH%)
# 0           0.0         0.02        26.88       71.16
# 1           0.0         0.02        26.88       71.16
# 2           0.0         0.02        26.88       71.18
# 3           0.0         0.02        26.88       71.19
# 4           0.0         0.02        26.88       71.21
#
# [5 rows x 26 columns]

# %%
data.isnull().sum()
# Out:
# Date                 0
# z1_AC1(kW)       67029
# z1_AC2(kW)       67029
# z1_AC3(kW)       67029
# z1_AC4(kW)       59627
# z1_Light(kW)     59243
# z1_Plug(kW)      59178
# z1_S1(degC)     163620
# z1_S1(RH%)      163620
# z1_S1(lux)      163620
# z2_AC1(kW)       59622
# z2_Light(kW)     59474
# z2_Plug(kW)      59166
# z2_S1(degC)     163065
# z2_S1(RH%)      163065
# z2_S1(lux)      163065
# z3_Light(kW)     59209
# z3_Plug(kW)      59216
# z4_AC1(kW)       59626
# z4_Light(kW)     59758
# z4_Plug(kW)      59450
# z4_S1(degC)     164511
# z4_S1(RH%)      164511
# z4_S1(lux)      164511
# z5_AC1(kW)       59626
# z5_Light(kW)     59758
# z5_Plug(kW)      59226
# z5_S1(degC)     194720
# z5_S1(RH%)      194720
# z5_S1(lux)      194720
# dtype: int64

# %%
#With consideration that null means no consumptions
data.fillna(0,inplace=True)

# %%
data.isnull().sum()
# Out:
# Date            0
# z1_AC1(kW)      0
# z1_AC2(kW)      0
# z1_AC3(kW)      0
# z1_AC4(kW)      0
# z1_Light(kW)    0
# z1_Plug(kW)     0
# z1_S1(degC)     0
# z1_S1(RH%)      0
# z1_S1(lux)      0
# z2_AC1(kW)      0
# z2_Light(kW)    0
# z2_Plug(kW)     0
# z2_S1(degC)     0
# z2_S1(RH%)      0
# z2_S1(lux)      0
# z3_Light(kW)    0
# z3_Plug(kW)     0
# z4_AC1(kW)      0
# z4_Light(kW)    0
# z4_Plug(kW)     0
# z4_S1(degC)     0
# z4_S1(RH%)      0
# z4_S1(lux)      0
# z5_AC1(kW)      0
# z5_Light(kW)    0
# z5_Plug(kW)     0
# z5_S1(degC)     0
# z5_S1(RH%)      0
# z5_S1(lux)      0
# dtype: int64

# %%
data.hist(figsize=(20,20),bins=50,xlabelsize=8,ylabelsize=8)
# Out:
# array([[<Axes: title={'center': 'z1_AC1(kW)'}>,
#         <Axes: title={'center': 'z1_AC2(kW)'}>,
#         <Axes: title={'center': 'z1_AC3(kW)'}>,
#         <Axes: title={'center': 'z1_AC4(kW)'}>,
#         <Axes: title={'center': 'z1_Light(kW)'}>],
#        [<Axes: title={'center': 'z1_Plug(kW)'}>,
#         <Axes: title={'center': 'z1_S1(degC)'}>,
#         <Axes: title={'center': 'z1_S1(RH%)'}>,
#         <Axes: title={'center': 'z1_S1(lux)'}>,
#         <Axes: title={'center': 'z2_AC1(kW)'}>],
#        [<Axes: title={'center': 'z2_Light(kW)'}>,
#         <Axes: title={'center': 'z2_Plug(kW)'}>,
#         <Axes: title={'center': 'z2_S1(degC)'}>,
#         <Axes: title={'center': 'z2_S1(RH%)'}>,
#         <Axes: title={'center': 'z2_S1(lux)'}>],
#        [<Axes: title={'center': 'z3_Light(kW)'}>,
#         <Axes: title={'center': 'z3_Plug(kW)'}>,
#         <Axes: title={'center': 'z4_AC1(kW)'}>,
#         <Axes: title={'center': 'z4_Light(kW)'}>,
#         <Axes: title={'center': 'z4_Plug(kW)'}>],
#        [<Axes: title={'center': 'z4_S1(degC)'}>,
#         <Axes: title={'center': 'z4_S1(RH%)'}>,
#         <Axes: title={'center': 'z4_S1(lux)'}>,
#         <Axes: title={'center': 'z5_AC1(kW)'}>,
#         <Axes: title={'center': 'z5_Light(kW)'}>],
#        [<Axes: title={'center': 'z5_Plug(kW)'}>,
#         <Axes: title={'center': 'z5_S1(degC)'}>,
#         <Axes: title={'center': 'z5_S1(RH%)'}>,
#         <Axes: title={'center': 'z5_S1(lux)'}>, <Axes: >]], dtype=object)

# %%
data.head()
# Out:
#                   Date  z1_AC1(kW)  z1_AC2(kW)  z1_AC3(kW)  z1_AC4(kW)  \
# 0  2018-07-01 00:00:00         0.0         0.0         0.0        0.07
# 1  2018-07-01 00:01:00         0.0         0.0         0.0        0.07
# 2  2018-07-01 00:02:00         0.0         0.0         0.0        0.07
# 3  2018-07-01 00:03:00         0.0         0.0         0.0        0.07
# 4  2018-07-01 00:04:00         0.0         0.0         0.0        0.07
#
#    z1_Light(kW)  z1_Plug(kW)  z1_S1(degC)  z1_S1(RH%)  z1_S1(lux)  ...  \
# 0           0.0         0.03        28.44       60.67         0.0  ...
# 1           0.0         0.03        28.44       60.67         0.0  ...
# 2           0.0         0.03        28.45       60.67         0.0  ...
# 3           0.0         0.03        28.45       60.66         0.0  ...
# 4           0.0         0.03        28.45       60.66         0.0  ...
#
#    z4_Plug(kW)  z4_S1(degC)  z4_S1(RH%)  z4_S1(lux)  z5_AC1(kW)  z5_Light(kW)  \
# 0         0.02        27.69       65.66         0.0         0.0           0.0
# 1         0.02        27.69       65.65         0.0         0.0           0.0
# 2         0.02        27.69       65.63         0.0         0.0           0.0
# 3         0.02         0.00        0.00         0.0         0.0           0.0
# 4         0.02         0.00        0.00         0.0         0.0           0.0
#
#    z5_Plug(kW)  z5_S1(degC)  z5_S1(RH%)  z5_S1(lux)
# 0         0.02        26.88       71.16         0.0
# 1         0.02        26.88       71.16         0.0
# 2         0.02        26.88       71.18         0.0
# 3         0.02        26.88       71.19         0.0
# 4         0.02        26.88       71.21         0.0
#
# [5 rows x 30 columns]

# %%
data.to_csv('drive/MyDrive/Intent-Based Energy Reduction/Data/Floor3_cleaned.csv',index=False)
